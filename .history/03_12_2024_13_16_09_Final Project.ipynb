# %% [markdown]
# ## Exploring Key Factors Influencing GitHub Repository Popularity

# %% [markdown]
# ## Introduction

# %% [markdown]
# ## Methods and Results
# Method
# forward/backward?
# Then compare the adjust r square
# pick the best predictor
# include interaction term?
# need prediction?
# if need, into training and
# Interpretation

# %% [markdown]
# ## Discussion
#
# conclusion

# %% [markdown]
# ## References

# %%
# test
